# %% [markdown]
# # Final Project Part 1 - Proposal
#
# For my final project I'll be using a dataset for AirBnb listings in the Los Angeles area.
#
# **Hypothesis, Assumptions, and Goals**
#
# I want to use this data in order to predict the pricing of an AirBnB listing.  I believe the type of listing and location of the listing affects the pricing.  I believe that being able to predict the pricing of a listing would help potential hosts make a decision if they would share their accommodations.
#
# **Risks and Limitations**
#
# The main limitation to this data is that its only listings from the Los Angeles area.  The model would only be benifitial to potential hosts in the LA area.  Other limitations are potential outliers from the area, such as mansions, or housing with large number of rooms which would fetch higher prices throwing off the accuracy of the predictive model.
#
# **Evaluation**
#
# There are 95 columns but there are a few that don't seem to be useful in predecting the price of the AirBnB.  There will have to be data manipulation for missing rows, converting of data into useable factors.  'room_type' will have to be broken up into a numerical category to be able to differentiate between differnt types of AirBnBs.

# %%
import pandas as pd

# %%
la_airbnbs = pd.read_csv('../data/la_airbnb_retail_listings.csv', low_memory = False)

# %%
la_airbnbs.shape
# Out:
# (31253, 95)

# %%
la_airbnbs.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  16228948  https://www.airbnb.com/rooms/16228948  20170502172350
# 1   8909380   https://www.airbnb.com/rooms/8909380  20170502172350
# 2  14078522  https://www.airbnb.com/rooms/14078522  20170502172350
# 3  13006928  https://www.airbnb.com/rooms/13006928  20170502172350
# 4   7898757   https://www.airbnb.com/rooms/7898757  20170502172350
#
#   last_scraped                                             name  \
# 0   2017-05-03  Robert Ranch in Los Angeles for filming/wedding
# 1   2017-05-03                   Nice quiet private ranch house
# 2   2017-05-03               Room w/private bath on Small Ranch
# 3   2017-05-03                           Miller Ranch Bunkhouse
# 4   2017-05-03                        Studio with full bathroom
#
#                                              summary  \
# 0  Stunning Ranch Estate situated on 20 acres and...
# 1                                                NaN
# ...

# %%
la_airbnbs.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
# ...

# %%
la_airbnbs.loc[:, 'room_type'].head()
# Out:
# 0    Entire home/apt
# 1       Private room
# 2       Private room
# 3    Entire home/apt
# 4       Private room
# Name: room_type, dtype: object

# %%
la_airbnbs.isna().sum()
# Out:
# id                                      0
# listing_url                             0
# scrape_id                               0
# last_scraped                            0
# name                                    7
# summary                               836
# space                                9387
# description                            15
# experiences_offered                     0
# neighborhood_overview               12678
# notes                               17438
# transit                             13089
# access                              12179
# interaction                         12991
# house_rules                          9206
# thumbnail_url                        4758
# medium_url                           4758
# picture_url                             0
# xl_picture_url                       4758
# host_id                                 0
# host_url                                0
# host_name                              14
# ...
